# %%
import mcstasscript as ms
from templateSANS_Mantid_generated import make

# %%
instr=make()

# %%
# Use instr.settings() to add e.g. seed=1000, ncount=1e7, mpi=8, openacc=True, force_compile=False etc.)

# %%
# Show diagram
instr.show_diagram()

# %%
# Visualise with default parameters (defaults to 'webgl-classic' visualisation - specify by format='window' for pyqtgraph)
instr.show_instrument()
# Out:
# Traceback (most recent call last):
#   File "/Users/peterwillendrup/micromamba/envs/ess-conda-env/share/mcstas/tools/Python/mcdisplay/webgl-classic/mcdisplay.py", line 199, in <module>
#     main(**args)
#   File "/Users/peterwillendrup/micromamba/envs/ess-conda-env/share/mcstas/tools/Python/mcdisplay/webgl-classic/mcdisplay.py", line 166, in main
#     instrument = reader.read_instrument()
#                  ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/peterwillendrup/micromamba/envs/ess-conda-env/share/mcstas/tools/Python/mccodelib/mcdisplayutils.py", line 46, in read_instrument
#     self.pipeman.join()
#   File "/Users/peterwillendrup/micromamba/envs/ess-conda-env/share/mcstas/tools/Python/mccodelib/pipetools.py", line 345, in join
#     raise self.reader.exc_obj
#   File "/Users/peterwillendrup/micromamba/envs/ess-conda-env/share/mcstas/tools/Python/mccodelib/pipetools.py", line 284, in run
#     raise Exception("TraceReader - mcrun process exited with code: %s" % str(poll))
# Exception: TraceReader - mcrun process exited with code: 255
#
# loading system configuration
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
# -> SPLIT N at component sampleMantid
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
# -> SPLIT within buffer at component sampleMantid
#
# -----------------------------------------------------------
# WARNING: Full-path compiler "${CONDA_PREFIX}/bin/arm64-apple-darwin20.0.0-clang" not found!!
# WARNING: Attempting replacement by "arm64-apple-darwin20.0.0-clang"
# INFO: Using directory: "templateSANS_Mantid_generated_mcdisplay"
# INFO: Regenerating c-file: templateSANS_Mantid_generated.c
# Info:    'PSD_monitor_rad' is a contributed component.
# CFLAGS=   @NEXUSFLAGS@
# INFO: Recompiling: ./templateSANS_Mantid_generated.out
# ./templateSANS_Mantid_generated.c:1210:10: fatal error: 'napi.h' file not found
# 1210 | #include "napi.h"
# |          ^~~~~~~~
# 1 error generated.
# INFO: call to arm64-apple-darwin20.0.0-clang failed with Command 'arm64-apple-darwin20.0.0-clang -o ./templateSANS_Mantid_generated.out ./templateSANS_Mantid_generated.c -lm -headerpad_max_install_names -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -isystem /Users/peterwillendrup/micromamba/envs/ess-conda-env/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/mcstas-suite_1761683326526/work=/usr/local/src/conda/mcstas-core-3.5.38 -fdebug-prefix-map=/Users/peterwillendrup/micromamba/envs/ess-conda-env=/usr/local/src/conda-prefix -O2 -g -DNDEBUG -isysroot /Applications/Xcode.app/Contents/Developer/Platforms/MacOSX.platform/Developer/SDKs/MacOSX.sdk -D_DARWIN_C_SOURCE '-I${CONDA_PREFIX}/include' '-Wl,-rpath,${CONDA_PREFIX}/lib' '-L${CONDA_PREFIX}/lib' -fno-PIC -fPIE -flto -O3 -fno-math-errno -ftree-vectorize -g -DNDEBUG -D_POSIX_SOURCE -std=c99 -lm '-Wl,-rpath,${CONDA_PREFIX}/lib' '-L${CONDA_PREFIX}/lib' -DUSE_NEXUS '-I${CONDA_PREFIX}/include/nexus' '-Wl,-rpath,${CONDA_PREFIX}/lib' '-L${CONDA_PREFIX}/lib' -lNeXus '-I${CONDA_PREFIX}/include/nexus'' returned non-zero exit status 1.
# ERROR: Compilation failed for ./templateSANS_Mantid_generated.c using compiler arm64-apple-darwin20.0.0-clang
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
# -> SPLIT N at component sampleMantid
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
# -> SPLIT within buffer at component sampleMantid
#
# -----------------------------------------------------------
#
#
#
# mcdisplay run failed.

# %%
# Generate a dataset with default parameters.
data = instr.backengine()
# Out:
# ---- Found 3 places in McStas output with keyword 'error'.
#
# ./templateSANS_Mantid_generated.c:1210:10: fatal error: 'napi.h' file not found
#  1210 | #include "napi.h"
#       |          ^~~~~~~~
# ----------------------------------------------------------------------
# 1 error generated.
# INFO: call to arm64-apple-darwin20.0.0-clang failed with Command 'arm64-apple-darwin20.0.0-clang -o ./templateSANS_Mantid_generated.out ./templateSANS_Mantid_generated.c -lm -headerpad_max_install_names -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -isystem /Users/peterwillendrup/micromamba/envs/ess-conda-env/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/mcstas-suite_1761683326526/work=/usr/local/src/conda/mcstas-core-3.5.38 -fdebug-prefix-map=/Users/peterwillendrup/micromamba/envs/ess-conda-env=/usr/local/src/conda-prefix -O2 -g -DNDEBUG -isysroot /Applications/Xcode.app/Contents/Developer/Platforms/MacOSX.platform/Developer/SDKs/MacOSX.sdk -D_DARWIN_C_SOURCE '-I${CONDA_PREFIX}/include' '-Wl,-rpath,${CONDA_PREFIX}/lib' '-L${CONDA_PREFIX}/lib' -fno-PIC -fPIE -flto -O3 -fno-math-errno -ftree-vectorize -g -DNDEBUG -D_POSIX_SOURCE -std=c99 -lm '-Wl,-rpath,${CONDA_PREFIX}/lib' '-L${CONDA_PREFIX}/lib' -DUSE_NEXUS '-I${CONDA_PREFIX}/include/nexus' '-Wl,-rpath,${CONDA_PREFIX}/lib' '-L${CONDA_PREFIX}/lib' -lNeXus '-I${CONDA_PREFIX}/include/nexus'' returned non-zero exit status 1.
# ----------------------------------------------------------------------
# ERROR: Compilation failed for ./templateSANS_Mantid_generated.c using compiler arm64-apple-darwin20.0.0-clang
#
# ----------------------------------------------------------------------
#
# WARNING: Full-path compiler "${CONDA_PREFIX}/bin/arm64-apple-darwin20.0.0-clang" not found!!
# WARNING: Attempting replacement by "arm64-apple-darwin20.0.0-clang"
# INFO: Using directory: "/Users/peterwillendrup/Projects/Schools/2025/ISIS_November_2025/2_Wednesday_November_5th/4_McStas_+_Mantid/McStastoX/templateSANS_Mantid_generated"
# INFO: Regenerating c-file: templateSANS_Mantid_generated.c
# Info:    'PSD_monitor_rad' is a contributed component.
# CFLAGS=   @NEXUSFLAGS@
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
# -> SPLIT N at component sampleMantid
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
# -> SPLIT within buffer at component sampleMantid
#
# -----------------------------------------------------------
# INFO: Recompiling: ./templateSANS_Mantid_generated.out
# ./templateSANS_Mantid_generated.c:1210:10: fatal error: 'napi.h' file not found
#  1210 | #include "napi.h"
#       |          ^~~~~~~~
# 1 error generated.
# INFO: call to arm64-apple-darwin20.0.0-clang failed with Command 'arm64-apple-darwin20.0.0-clang -o ./templateSANS_Mantid_generated.out ./templateSANS_Mantid_generated.c -lm -headerpad_max_install_names -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -isystem /Users/peterwillendrup/micromamba/envs/ess-conda-env/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/mcstas-suite_1761683326526/work=/usr/local/src/conda/mcstas-core-3.5.38 -fdebug-prefix-map=/Users/peterwillendrup/micromamba/envs/ess-conda-env=/usr/local/src/conda-prefix -O2 -g -DNDEBUG -isysroot /Applications/Xcode.app/Contents/Developer/Platforms/MacOSX.platform/Developer/SDKs/MacOSX.sdk -D_DARWIN_C_SOURCE '-I${CONDA_PREFIX}/include' '-Wl,-rpath,${CONDA_PREFIX}/lib' '-L${CONDA_PREFIX}/lib' -fno-PIC -fPIE -flto -O3 -fno-math-errno -ftree-vectorize -g -DNDEBUG -D_POSIX_SOURCE -std=c99 -lm '-Wl,-rpath,${CONDA_PREFIX}/lib' '-L${CONDA_PREFIX}/lib' -DUSE_NEXUS '-I${CONDA_PREFIX}/include/nexus' '-Wl,-rpath,${CONDA_PREFIX}/lib' '-L${CONDA_PREFIX}/lib' -lNeXus '-I${CONDA_PREFIX}/include/nexus'' returned non-zero exit status 1.
# ERROR: Compilation failed for ./templateSANS_Mantid_generated.c using compiler arm64-apple-darwin20.0.0-clang
# /Users/peterwillendrup/micromamba/envs/ess-conda-env/lib/python3.12/site-packages/mcstasscript/helper/managed_mcrun.py:299: UserWarning: Simulation did not create data folder, most likely failed.
#   warnings.warn("Simulation did not create data folder, most likely failed.")
# /Users/peterwillendrup/micromamba/envs/ess-conda-env/lib/python3.12/site-packages/mcstasscript/helper/managed_mcrun.py:327: UserWarning: No data available to load.
#   warnings.warn("No data available to load.")

# %%
# Overview plot:
ms.make_sub_plot(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Overview plot:
# ----> 2 ms.make_sub_plot(data)
#
# File ~/micromamba/envs/ess-conda-env/lib/python3.12/site-packages/mcstasscript/interface/plotter.py:55, in make_sub_plot(data_list, **kwargs)
#      44 def make_sub_plot(data_list, **kwargs):
#      45     """
#      46     make_sub_plot plots contents of McStasData objects given in list
#      47
#    (...)     52     subplot.
#      53     """
# ---> 55     data_list = _handle_kwargs(data_list, **kwargs)
#      57     number_of_plots = len(data_list)
#      58     if number_of_plots == 0:
#
# File ~/micromamba/envs/ess-conda-env/lib/python3.12/site-packages/mcstasscript/helper/plot_helper.py:269, in _handle_kwargs(data_list, **kwargs)
#     266     data_list = [data_list]
#     268 # Remove event data that can't be plotted in meaningful way
# --> 269 data_list = remove_eventdata(data_list)
#     271 known_plotting_kwargs = ["log", "orders_of_mag",
#     272                          "top_lim", "bottom_lim",
#     273                          "left_lim", "right_lim",
#    (...)    276                          "x_axis_multiplier",
#     277                          "y_axis_multiplier"]
#     279 for option in known_plotting_kwargs:
#
# File ~/micromamba/envs/ess-conda-env/lib/python3.12/site-packages/mcstasscript/helper/plot_helper.py:20, in remove_eventdata(data_list, verbose)
#      18 reduced_data_list = []
#      19 skipped_names = []
# ---> 20 for element in data_list:
#      21     if not isinstance(element, McStasDataEvent):
#      22         reduced_data_list.append(element)
#
# TypeError: 'NoneType' object is not iterable

# %%
# Other useful commands follow...
# One plot pr. window
#ms.make_plot(data)

# %%
# Load another dataset
#data2 = ms.load_data('some_other_folder')

# %%
# Adjusting a specific plot
#ms.name_plot_options(\"PSD_4PI\", data, log=1, colormap=\"hot\", orders_of_mag=5)

# %%
# Bring up the 'interface' - only relevant in Jupyter
#%matplotlib widget
#import mcstasscript.jb_interface as ms_widget
#ms_widget.show(data)

# %%
# Bring up the simulation 'interface' - only relevant in Jupyter
#%matplotlib widget
#import mcstasscript.jb_interface as ms_widget
#sim_widget = ms_widget.SimInterface(instr)
#sim_widget.show_interface()

# %%
# Acessing data from the interface
#data = sim_widget.get_data()
